# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
model_client = OpenAIChatCompletionClient(model='gpt-4o-mini')

# %%
assitant = AssistantAgent(name='assitant', model_client=model_client, description='basic agent')

# %%
result = await assitant.run(task='what is the capital of hyderabad-india')
result
# Out:
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='what is the capital of hyderabad-india', type='TextMessage'), TextMessage(source='assitant', models_usage=RequestUsage(prompt_tokens=45, completion_tokens=36), metadata={}, content='The capital of the Indian state of Telangana is Hyderabad. It is also the de jure capital of Andhra Pradesh. Hyderabad is known for its rich history, culture, and cuisine.', type='TextMessage')], stop_reason=None)

# %%
result.messages[-1].content
# Out:
# 'The capital of the Indian state of Telangana is Hyderabad. It is also the de jure capital of Andhra Pradesh. Hyderabad is known for its rich history, culture, and cuisine.'

# %%
print(result.messages)
# Out:
# [TextMessage(source='user', models_usage=None, metadata={}, content='what is the capital of hyderabad-india', type='TextMessage'), TextMessage(source='assitant', models_usage=RequestUsage(prompt_tokens=45, completion_tokens=36), metadata={}, content='The capital of the Indian state of Telangana is Hyderabad. It is also the de jure capital of Andhra Pradesh. Hyderabad is known for its rich history, culture, and cuisine.', type='TextMessage')]
